# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300
import numpy as np
import pickle

import sys
import os

# Adding parent directory to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
from src import colony
from util import plotter

# %%
# Generate plots for 3 models
nSLs = [10, 100, 1000]
for nSL in nSLs:
    filename = '../results/nSLConvergence/' + str(nSL) + 'SL' + '/model.pkl'
    with open(filename, 'rb') as handle:
        col = pickle.load(handle)
    plotter.plotFlowRate(col)
    # plotter.plotFlowRate(col, path = '../figures/SL%dflow.png' %nSL)
